# %% [markdown]
# Assignment 8 th september
# 1.Take car crashes dataset from seaborn library
# 2.load the dataset
# 3.data visualiation
# 4.Inference is must for each and every graph
# 5.Submit it by wednesday in html format

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = sns.load_dataset('car_crashes')
df
# Out:
#     total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0    18.8     7.332    5.640          18.048       15.040       784.55
# 1    18.1     7.421    4.525          16.290       17.014      1053.48
# 2    18.6     6.510    5.208          15.624       17.856       899.47
# 3    22.4     4.032    5.824          21.056       21.280       827.34
# 4    12.0     4.200    3.360          10.920       10.680       878.41
# 5    13.6     5.032    3.808          10.744       12.920       835.50
# 6    10.8     4.968    3.888           9.396        8.856      1068.73
# 7    16.2     6.156    4.860          14.094       16.038      1137.87
# 8     5.9     2.006    1.593           5.900        5.900      1273.89
# 9    17.9     3.759    5.191          16.468       16.826      1160.13
# 10   15.6     2.964    3.900          14.820       14.508       913.15
# 11   17.5     9.450    7.175          14.350       15.225       861.18
# ...

# %%
sns.scatterplot(x="total",y="alcohol",data=df)
# Out:
# <Axes: xlabel='total', ylabel='alcohol'>

# %% [markdown]
# inference : total crtashes increases with the alcohol quantity

# %%
sns.lineplot(x="total",y="alcohol",data=df,errorbar=None)
# Out:
# <Axes: xlabel='total', ylabel='alcohol'>

# %% [markdown]
# INferences : alcohol quantity increases with the total car crashes

# %%
sns.distplot(df["alcohol"])
# Out:
# <ipython-input-16-281d56044cde>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["alcohol"])
# <Axes: xlabel='alcohol', ylabel='Density'>

# %% [markdown]
# inference : the most common alcohol point is 4 to 6 , increasing and then decreasing

# %%
sns.distplot(df["not_distracted"])
# Out:
# <ipython-input-17-88e0b855dbfb>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["not_distracted"])
# <Axes: xlabel='not_distracted', ylabel='Density'>

# %% [markdown]
# INference : not distracted during car crash densityy increases till 15 and then decreases

# %%
sns.boxplot(x="total",y="alcohol",data=df)
# Out:
# <Axes: xlabel='total', ylabel='alcohol'>

# %% [markdown]
# Inference : total crashes increases with the increase consuption of alcohol

# %%
sns.barplot(x="total",y="alcohol",data=df)
# Out:
# <Axes: xlabel='total', ylabel='alcohol'>

# %% [markdown]
# inference : this barplot shows how there is a gradual increase in total crashes with increase in alcohol
